# %% [markdown]
# <a href="https://colab.research.google.com/github/Isaraq/Lab7/blob/main/Lab7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_style('whitegrid')

# %matplotlib inline

# %% [markdown]
# # **The Data**
#
# ---

# %%
df = pd.read_csv("heart.csv")
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %%
df.describe()
# Out:
#                age          sex           cp     trestbps        chol  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.00000
# mean     54.434146     0.695610     0.942439   131.611707   246.00000
# std       9.072290     0.460373     1.029641    17.516718    51.59251
# min      29.000000     0.000000     0.000000    94.000000   126.00000
# 25%      48.000000     0.000000     0.000000   120.000000   211.00000
# 50%      56.000000     1.000000     1.000000   130.000000   240.00000
# 75%      61.000000     1.000000     2.000000   140.000000   275.00000
# max      77.000000     1.000000     3.000000   200.000000   564.00000
#
#                fbs      restecg      thalach        exang      oldpeak  \
# count  1025.000000  1025.000000  1025.000000  1025.000000  1025.000000
# mean      0.149268     0.529756   149.114146     0.336585     1.071512
# std       0.356527     0.527878    23.005724     0.472772     1.175053
# ...

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # Exploratory Data Analysis
#
#
# ---
#
#
#
# ## Missing Data

# %%
sns.heatmap(df.isnull(), yticklabels=False, cbar=False, cmap='viridis')
# Out:
# <Axes: >

# %% [markdown]
# The heatmap shows that there are no missing values in the dataset.
# This means the dataset is clean and does not require data imputation.
#
# ---

# %% [markdown]
# # **Visualization**
#
# ---

# %% [markdown]
# ### Target Distribution

# %%
sns.countplot(x='target', data=df)
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Heart Disease'])
plt.show()

# %% [markdown]
# The plot shows the distribution of the target variable.
# The dataset is relatively balanced between patients with and without heart disease.
#
#
# ---

# %% [markdown]
# ## **Countplot (target vs sex)**

# %%
sns.countplot(x='target', hue='sex', data=df)
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Heart Disease'])
plt.legend(title='Sex', labels=['Female', 'Male'])
plt.show()

# %% [markdown]
# This plot shows the relationship between gender and heart disease.

# %% [markdown]
# ---
#
# ### Age Distribution

# %%
sns.histplot(df['age'], bins=30)
plt.show()

# %% [markdown]
# ---
#
# ### Max Heart Rate (thalach)

# %%
sns.histplot(df['thalach'], bins=30)
plt.show()

# %% [markdown]
# ---
# ## Histogram (chol)

# %%
sns.histplot(df['chol'], bins=30)
plt.show()

# %% [markdown]
# ---
# ## **Countplot (fbs)**

# %%
sns.countplot(x='fbs', data=df)
plt.xticks(ticks=[0, 1], labels=['fbs <= 120 mg/dl', 'fbs > 120 mg/dl'])
plt.show()

# %% [markdown]
# ---
# ### Gender Distribution

# %%
sns.countplot(x='sex', data=df)
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])
plt.show()

# %% [markdown]
# ---
#
#
# ## **Boxplot (age vs target)**

# %%
plt.figure(figsize=(8,6))
sns.boxplot(x='target', y='age', data=df)
plt.xticks(ticks=[0, 1], labels=['No Disease', 'Heart Disease'])
plt.show()

# %% [markdown]
# The boxplot shows the relationship between age and heart disease.
# It helps visualize how age varies between patients with and without heart disease.

# %% [markdown]
# ---

# %%
import seaborn as sns

sns.heatmap(confusion_matrix(y_test, predictions), annot=True, fmt='d')
plt.show()

# %% [markdown]
# #**Data Cleaning**
#
# ---
# The dataset is clean and does not contain missing values.
# No data cleaning is required.

# %% [markdown]
# # **Converting Categorical Features**
#
# ---
# Most features are already numerical, so no conversion is needed.

# %% [markdown]
# # **Building a Logistic Regression Model**
#
#
# ---
# ## **Train Test Split**

# %%
from sklearn.model_selection import train_test_split

X = df.drop('target', axis=1)
y = df['target']

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %% [markdown]
# ## **Training and Predicting**

# %%
from sklearn.linear_model import LogisticRegression

logmodel = LogisticRegression(max_iter=1000)
logmodel.fit(X_train, y_train)

predictions = logmodel.predict(X_test)

# %% [markdown]
# ## **Evaluation**

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

print(confusion_matrix(y_test, predictions))
print("Accuracy:", accuracy_score(y_test, predictions))
# Out:
# [[119  40]
#  [ 20 129]]
# Accuracy: 0.8051948051948052

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.75      0.80       159
#            1       0.76      0.87      0.81       149
#
#     accuracy                           0.81       308
#    macro avg       0.81      0.81      0.80       308
# weighted avg       0.81      0.81      0.80       308
